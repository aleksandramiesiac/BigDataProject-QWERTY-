# %%
from requests_html import HTMLSession
import urllib3
import requests
from bs4 import BeautifulSoup
session = HTMLSession()

# link = "http://www.azair.eu/azfin.php?tp=0&searchtype=flexi&srcAirport=Germany+%5BSXF%5D+%28%2BTXL%2CLEJ%2CDRS%2CHDF%2CRLG%2CERF%2CFRA%2CFMO%2CHAM%2CCGN%2CDUS%2CMUC%2CNUE%2CSCN%2CSTR%2CHAJ%2CBRE%2CHHN%2C\
# PAD%2CDTM%2CFDH%2CGWT%2CFMM%2CFKB%2CNRN%29&srcTypedText=Ge&srcFreeTypedText=&srcMC=DE&srcap0=TXL&srcap1=LEJ&srcap2=DRS&srcap4=HDF&srcap5=RLG&srcap7=ERF&srcap10=FRA&srcap11=FMO&srcap12=HAM&srcap13=CGN&srca\
# p14=DUS&srcap15=MUC&srcap16=NUE&srcap17=SCN&srcap18=STR&srcap19=HAJ&srcap20=BRE&srcap21=HHN&srcap22=PAD&srcap23=DTM&srcap24=FDH&srcap25=GWT&srcap26=FMM&srcap27=FKB&srcap28=NRN&srcFreeAirport=&dstAirport=An\
# ywhere+%5BXXX%5D&dstTypedText=anywhere&dstFreeTypedText=&dstMC=&adults=1&children=0&infants=0&minHourStay=0%3A00&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&ma\
# xHourInbound=24%3A00&depdate=7.4.2019&arrdate=31.3.2020&minDaysStay=5&maxDaysStay=8&nextday=0&autoprice=true&currency=EUR&wizzxclub=false&supervolotea=false&schengen=false&transfer=false&samedep=true&same\
# arr=true&dep0=true&dep1=false&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&maxChng=1&isOneway=return&resultSubmit=Search"

# link = "http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=United+States+%5BBOS%5D+%28%2BPVD%2CBDL%2CSWF%2CJFK%2CEWR%2COAK%2CSFO%2CLAX%2CFLL%2CMIA%2CSEA%2CDTW%2CIAD%2CHNL%2CDEN%\
# 2CRSW%2CORD%2CBWI%2CMSP%2CLAS%2CMCO%29&srcap0=PVD&srcap1=BDL&srcap2=SWF&srcap3=JFK&srcap4=EWR&srcap5=OAK&srcap6=SFO&srcap7=LAX&srcap8=FLL&srcap9=MIA&srcap10=SEA&srcap11=DTW&srcap12=IAD&srcap13=HNL&srcap14\
# =DEN&srcap15=RSW&srcap16=ORD&srcap17=BWI&srcap18=MSP&srcap19=LAS&srcap20=MCO&srcFreeAirport=&srcTypedText=Un&srcFreeTypedText=&srcMC=US&dstAirport=Anywhere+%5BXXX%5D&anywhere=true&dstTypedText=anywhere&d\
# stFreeTypedText=&dstMC=&depmonth=201904&depdate=2019-04-07&aid=0&arrmonth=202003&arrdate=2020-03-31&minDaysStay=5&maxDaysStay=8&dep0=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=\
# true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A00&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound\
# =24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&currency=EUR&indexSubmit=Search"

# link = "http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Moscow+%5BDME%5D+%28%2BZIA%2CVKO%2CSVO%29&srcap0=ZIA&srcap1=VKO&srcap2=SVO&srcFreeAirport=&srcTypedText=Mos&srcFree\
# TypedText=&srcMC=MOW_ALL&dstAirport=Anywhere+%5BXXX%5D&anywhere=true&dstTypedText=anywhere&dstFreeTypedText=&dstMC=&depmonth=201904&depdate=2019-04-07&aid=0&arrmonth=202003&arrdate=2020-03-31&minDaysSta\
# y=5&maxDaysStay=8&dep0=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A00&maxHourSt\
# ay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&nextday=true&currency=EUR&indexSubmit=Search"


# r = session.get( "http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Wroclaw+%5BWRO%5D+%28%2BPOZ%2CKTW%2CPRG%2CKRK%29&srcap1=POZ&srcap2=KTW&\
# srcap5=PRG&srcap9=KRK&srcFreeAirport=&srcTypedText=pra&srcFreeTypedText=&srcMC=&dstAirport=Milan+%5BMXP%5D+%28%2BLIN%2CBGY%29&dstap0=LIN&dstap1=BGY&dstFreeAirport=&dst\
# TypedText=mil&dstFreeTypedText=&dstMC=MIL_ALL&depmonth=201903&depdate=2019-03-20&aid=0&arrmonth=202003&arrdate=2020-03-19&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=\
# true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%\
# 3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&max\
# Chng=1&currency=EUR&indexSubmit=Search")

# r = session.get("http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&\
# srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=Anywhe\
# re+%5BXXX%5D&anywhere=true&dstap0=LIN&dstap1=BGY&dstFreeAirport=&dstTypedText=anywhere&dstFreeTypedText=&dstMC=&depmonth=201904&depdate=2019-04-07&aid=0&arrmonth=202003&arrdate=2020-03-19&minDaysStay=5&ma\
# xDaysStay=8&dep0=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A00&maxHourStay=23%3A\
# 20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&currency=EUR&indexSubmit=Search")
# link = 'http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=Italy+%5BCRV%5D+%28%2BSUF%2CREG%2CBDS%2CBRI%2CCTA%2CCIY%2CNAP%2CPSR%2CLMP%2CPNL%2CPMO%2CTPS%2CAHO%2CCAG%2COLB%2CMXP%2CBGY%2CTRN%2CGOA%2CLIN%2CPMF%2CCUF%2CBLQ%2CTSF%2CTRS%2CRMI%2CVRN%2CVCE%2CCIA%2CFCO%2CPSA%2CFLR%2CPEG%2CAOI%29&dstap0=SUF&dstap1=REG&dstap2=BDS&dstap3=BRI&dstap4=CTA&dstap6=CIY&dstap8=NAP&dstap10=PSR&dstap11=LMP&dstap12=PNL&dstap13=PMO&dstap14=TPS&dstap15=AHO&dstap16=CAG&dstap17=OLB&dstap18=MXP&dstap19=BGY&dstap20=TRN&dstap21=GOA&dstap22=LIN&dstap23=PMF&dstap24=CUF&dstap25=BLQ&dstap26=TSF&dstap27=TRS&dstap28=RMI&dstap29=VRN&dstap30=VCE&dstap31=CIA&dstap32=FCO&dstap33=PSA&dstap34=FLR&dstap35=PEG&dstap36=AOI&dstFreeAirport=&dstTypedText=ital&dstFreeTypedText=&dstMC=IT&depmonth=201904&depdate=2019-04-08&aid=0&arrmonth=202003&arrdate=2020-03-28&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&nextday=true&currency=EUR&indexSubmit=Search'
# link = 'http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=Tenerife+North+%5BTFN%5D&dstFreeAirport=&dstTypedText=Tene&dstFreeTypedText=&dstMC=&depmonth=201904&depdate=2019-04-08&aid=0&arrmonth=202003&arrdate=2020-03-28&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&nextday=true&currency=EUR&indexSubmit=Search'
# link = 'http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=Tenerife+South+%5BTFS%5D&dstFreeAirport=&dstTypedText=Tene&dstFreeTypedText=&dstMC=&depmonth=201904&depdate=2019-04-08&aid=0&arrmonth=202003&arrdate=2020-03-28&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&nextday=true&currency=EUR&indexSubmit=Search'
# link = 'http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=Spain+%5BFUE%5D+%28%2BACE%2CLPA%2CTFN%2CTFS%2CGMZ%2CVDE%2CSPC%2CALC%2CLEI%2COVD%2CBIO%2CBCN%2CLCG%2CGRO%2CGRX%2CIBZ%2CXRY%2CMJV%2CMAD%2CAGP%2CMAH%2CPNA%2CRMU%2CREU%2CEAS%2CSCQ%2CVLC%2CVLL%2CVIT%2CVGO%2CSDR%2CZAZ%2CSVQ%2CPMI%2CILD%2CCDT%29&dstap0=ACE&dstap2=LPA&dstap3=TFN&dstap4=TFS&dstap5=GMZ&dstap6=VDE&dstap7=SPC&dstap8=ALC&dstap9=LEI&dstap10=OVD&dstap11=BIO&dstap12=BCN&dstap13=LCG&dstap14=GRO&dstap15=GRX&dstap16=IBZ&dstap17=XRY&dstap18=MJV&dstap19=MAD&dstap20=AGP&dstap21=MAH&dstap22=PNA&dstap23=RMU&dstap24=REU&dstap25=EAS&dstap26=SCQ&dstap27=VLC&dstap28=VLL&dstap29=VIT&dstap30=VGO&dstap31=SDR&dstap32=ZAZ&dstap33=SVQ&dstap34=PMI&dstap35=ILD&dstap36=CDT&dstFreeAirport=&dstTypedText=spai&dstFreeTypedText=&dstMC=ES&depmonth=201904&depdate=2019-04-08&aid=0&arrmonth=202003&arrdate=2020-03-28&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&nextday=true&currency=EUR&indexSubmit=Search'
link ='http://www.azair.eu/azfin.php?searchtype=flexi&tp=0&isOneway=return&srcAirport=Poland+%5BSZY%5D+%28%2BWMI%2CWAW%2CGDN%2CBZG%2CLCJ%2CLUZ%2CPOZ%2CKRK%2CKTW%2CRZE%2CSZZ%2CWRO%29&srcap0=WMI&srcap1=WAW&srcap3=GDN&srcap4=BZG&srcap5=LCJ&srcap7=LUZ&srcap9=POZ&srcap10=KRK&srcap11=KTW&srcap12=RZE&srcap13=SZZ&srcap14=WRO&srcFreeAirport=&srcTypedText=pol&srcFreeTypedText=&srcMC=PL&dstAirport=France+%5BBOD%5D+%28%2BEGC%2CLRH%2CPUF%2CBIQ%2CBVE%2CLIG%2CLDE%2CPIS%2CTLS%2CRDZ%2CDLE%2CETZ%2CBIA%2CCLY%2CFSC%2CAJA%2CCMF%2CCFE%2CLYS%2CGNB%2CCCF%2CMRS%2CNCE%2CPGF%2CMPL%2CBZR%2CAVN%2CBVA%2CXCR%2CTUF%2CCDG%2CORY%2CLIL%2CBES%2CDNR%2CDOL%2CLRT%2CCFR%2CRNS%2CNTE%2CMLH%2CSXB%2CTLN%2CFNI%29&dstap0=EGC&dstap1=LRH&dstap2=PUF&dstap3=BIQ&dstap4=BVE&dstap6=LIG&dstap7=LDE&dstap8=PIS&dstap9=TLS&dstap10=RDZ&dstap11=DLE&dstap12=ETZ&dstap13=BIA&dstap14=CLY&dstap15=FSC&dstap16=AJA&dstap17=CMF&dstap18=CFE&dstap19=LYS&dstap20=GNB&dstap21=CCF&dstap22=MRS&dstap23=NCE&dstap24=PGF&dstap25=MPL&dstap26=BZR&dstap27=AVN&dstap28=BVA&dstap29=XCR&dstap30=TUF&dstap31=CDG&dstap32=ORY&dstap33=LIL&dstap34=BES&dstap35=DNR&dstap36=DOL&dstap37=LRT&dstap38=CFR&dstap39=RNS&dstap40=NTE&dstap41=MLH&dstap42=SXB&dstap43=TLN&dstap44=FNI&dstFreeAirport=&dstTypedText=FRA&dstFreeTypedText=&dstMC=FR&depmonth=201904&depdate=2019-04-08&aid=0&arrmonth=202003&arrdate=2020-03-28&minDaysStay=5&maxDaysStay=8&dep0=true&dep1=true&dep2=true&dep3=true&dep4=true&dep5=true&dep6=true&arr0=true&arr1=true&arr2=true&arr3=true&arr4=true&arr5=true&arr6=true&samedep=true&samearr=true&minHourStay=0%3A45&maxHourStay=23%3A20&minHourOutbound=0%3A00&maxHourOutbound=24%3A00&minHourInbound=0%3A00&maxHourInbound=24%3A00&autoprice=true&adults=1&children=0&infants=0&maxChng=1&nextday=true&currency=EUR&indexSubmit=Search'


r = session.get(link)

# %%
len(lista_linkow)
len(r.html.absolute_links)#to jest lepsze, z tego będziemy korzytsać
# Out:
# 966

# %%
tp = r.html.find('.tp')
skad = r.html.find('.from')
cena =r.html.find('.legPrice')
#list_of_variables = [".date", ".to", ".from", ".legPrice", ".time," ,".tp", "p"]
data = r.html.find('.date')
data = data[3:]
to =r.html.find('.to')
change = r.html.find('.durcha')
przewoznik = r.html.find('.airline')

# %%
len(skad)
print("Data: ", len(data) ," skad: ", len(skad), " dokąd: ", len(to), " cena: ", len(cena), len(przewoznik), len(change))
# Out:
# Data:  360  skad:  928  dokąd:  928  cena:  568 568 360

# %%
# suma=0
# jest=0
# niema=0
# for i in range(len(change)):
#     if change[i].full_text[9:11] =='no':
#         suma+=1
#         niema+=1
#     else:
#         suma+=2
#         jest+=1

# suma, niema, jest

# %%
f = open("Poland_France.txt", "w")
f.write("Data Przewoznik Czy_przesiadka Cena Godzina_odlotu Miejsce_odlotu Godzina_przylotu Miejsce_przylotu\n")
# Out:
# 100

# %%
licznik=0
ii=0
licz_ceny=0
i=0
while i+ii <len(change):
    przes=0
    if change[i+ii].full_text[9:11] !='no':
        przes=1

        f.write(str(data[i+ii].text[4:])+" "+str(przewoznik[licz_ceny].text)+" "+str(przes)+" "+str(cena[licz_ceny].text[1:])+" "+str(skad[licznik+1].text.replace('\xa0',' ')[3:8])+\
            " "+str(skad[licznik+1].text.replace('\xa0',' ')[9:])+" "+str(to[licznik].text[:5])+" "+str(to[licznik].text[6:])+"\n")
        licz_ceny+=1
        licznik+=1
        f.write(str(data[i+ii].text[4:])+" "+str(przewoznik[licz_ceny].text)+" "+str(przes)+" "+str(cena[licz_ceny].text[1:])+" "+str(skad[licznik+1].text.replace('\xa0',' ')[3:8])+\
            " "+str(skad[licznik+1].text.replace('\xa0',' ')[9:])+" "+str(to[licznik].text[:5])+" "+str(to[licznik].text[6:])+"\n")
        licz_ceny+=1
        licznik+=2
        ii+=1
    
    f.write(str(data[i+ii].text[4:])+" "+str(przewoznik[licz_ceny].text)+" "+str(przes)+" "+str(cena[licz_ceny].text[1:])+" "+str(skad[licznik+1].text.replace('\xa0',' ')[3:8])+\
            " "+str(skad[licznik+1].text.replace('\xa0',' ')[9:])+" "+str(to[licznik].text[:5])+" "+str(to[licznik].text[6:])+"\n")
    licz_ceny+=1
    licznik+=2
    i+=1

# %%
f.close()

# %%
licznik=0
ii=0
licz_ceny=0
for i in range(len(cena)):
#     if i %4==0:
      
#         print()
#         print("Data: ", data[2*i].text)
#     print(cena[i].text)
#     print("Stąd: ", skad[i].text)
    if change[i+ii].full_text[9:11] !='no':
        print("Change!")
        print(licznik, i+ii)
        print(cena[licz_ceny].text)
        print("Przewoznik: ",przewoznik[licz_ceny].text)
        licz_ceny+=1
        print("Data: ",data[i+ii].text)
        
        
        print("Stąd: ", skad[licznik+1].text,"  Dotąd: ", to[licznik+1].text)
#         print("Dotąd: ", to[licznik].text)
        licznik+=1
        print(cena[licz_ceny].text)
        print("Przewoznik: ",przewoznik[licz_ceny].text)
        licz_ceny+=1
        print("Stąd: ", skad[licznik+1].text, "   Dotąd: ", to[licznik-1].text)
        print()
        licznik+=2
        ii+=1
    print("Data: ",data[i+ii].text)
    print("Przewoznik: ",przewoznik[licz_ceny].text)
#     print(licznik, i+ii)
    print(change[i+ii].full_text[9:11])
    print(cena[licz_ceny].text)
    licz_ceny+=1
    print("Stąd: ", skad[licznik+1].text)    
    print("Dotąd: ", to[licznik].text) 
    licznik+=2
    print()
# Out:
# Data:  Soonest depart
# nespravne datum
# Latest return
# Nespravne datum
# Przewoznik:  Ryanair
# no
# €6.75
# Stąd:  We 07:10 Gdansk GDN
# Dotąd:  08:40 Oslo TRFOslo (Torp) TRF
#
# Data:
# Przewoznik:  Ryanair
# no
# €5.89
# Stąd:  Tu 09:05 Oslo TRFOslo (Torp) TRF
# Dotąd:  10:35 Gdansk GDN
#
# Data:
# Przewoznik:  Ryanair
# no
# €7.91
# Stąd:  We 06:40 Warsaw WMIWarsaw (Modlin) WMI
# Dotąd:  08:30 Oslo TRFOslo (Torp) TRF
#
# Data:  Wed 17/04/19
# Przewoznik:  Ryanair
# no
# €5.89
# Stąd:  We 08:55 Oslo TRFOslo (Torp) TRF
# Dotąd:  10:35 Warsaw WMIWarsaw (Modlin) WMI
#
# Data:  Tue 23/04/19
# Przewoznik:  Ryanair
# no
# €7.91
# Stąd:  Sa 08:00 Gdansk GDN
# Dotąd:  09:05 Vaxjo VXO
#
# Data:  Wed 17/04/19
# Przewoznik:  Ryanair
# no
# €7.28
# Stąd:  Su 16:30 Vaxjo VXO
# Dotąd:  17:35 Gdansk GDN
#
# Data:  Wed 24/04/19
# Przewoznik:  Ryanair
# no
# €7.91
# Stąd:  Sa 08:25 Gdansk GDN
# Dotąd:  09:40 Stockholm NYOStockholm (Skavsta) NYO
#
# Data:  Sat 20/04/19
# Przewoznik:  Ryanair
# ...
