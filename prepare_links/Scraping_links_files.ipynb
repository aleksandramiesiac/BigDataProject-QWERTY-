# %%
import pandas as pd

links = pd.read_csv("countries_links.txt",sep=";",header=None)

# %%
links
# Out:
#            0         1                                                  2
# 0    Austria   Austria  http://www.azair.eu/azfin.php?searchtype=flexi...
# 1    Austria   Belgium  http://www.azair.eu/azfin.php?searchtype=flexi...
# 2    Austria   Croatia  http://www.azair.eu/azfin.php?searchtype=flexi...
# 3    Austria   Denmark  http://www.azair.eu/azfin.php?searchtype=flexi...
# 4    Austria   England  http://www.azair.eu/azfin.php?searchtype=flexi...
# 5    Austria    France  http://www.azair.eu/azfin.php?searchtype=flexi...
# 6    Austria   Germany  http://www.azair.eu/azfin.php?searchtype=flexi...
# 7    Austria    Greece  http://www.azair.eu/azfin.php?searchtype=flexi...
# 8    Austria   Ireland  http://www.azair.eu/azfin.php?searchtype=flexi...
# 9    Austria     Italy  http://www.azair.eu/azfin.php?searchtype=flexi...
# 10   Austria    Norway  http://www.azair.eu/azfin.php?searchtype=flexi...
# 11   Austria    Poland  http://www.azair.eu/azfin.php?searchtype=flexi...
# ...

# %%
links[0].drop_duplicates().count()
# Out:
# 15

# %%
15*15
# Out:
# 225

# %%
225/4
# Out:
# 56.25

# %%
56+56+56+57
# Out:
# 225

# %%
links_dict = {}

for i in range(4):
    links_dict[i] = links.iloc[56*i:56*(i+1)]

# %%
links_dict[3] = links_dict[3].append(links.iloc[224])

# %%
links_dict[0].to_csv('scrap_links_1.txt',sep=';', index=False, header=False)

# %%
links_dict[1].to_csv('scrap_links_2.txt',sep=';', index=False, header=False)

# %%
links_dict[2].to_csv('scrap_links_3.txt',sep=';', index=False, header=False)

# %%
links_dict[3].to_csv('scrap_links_4.txt',sep=';', index=False, header=False)

# %%
links_dict[0]
# Out:
#           0         1                                                  2
# 0   Austria   Austria  http://www.azair.eu/azfin.php?searchtype=flexi...
# 1   Austria   Belgium  http://www.azair.eu/azfin.php?searchtype=flexi...
# 2   Austria   Croatia  http://www.azair.eu/azfin.php?searchtype=flexi...
# 3   Austria   Denmark  http://www.azair.eu/azfin.php?searchtype=flexi...
# 4   Austria   England  http://www.azair.eu/azfin.php?searchtype=flexi...
# 5   Austria    France  http://www.azair.eu/azfin.php?searchtype=flexi...
# 6   Austria   Germany  http://www.azair.eu/azfin.php?searchtype=flexi...
# 7   Austria    Greece  http://www.azair.eu/azfin.php?searchtype=flexi...
# 8   Austria   Ireland  http://www.azair.eu/azfin.php?searchtype=flexi...
# 9   Austria     Italy  http://www.azair.eu/azfin.php?searchtype=flexi...
# 10  Austria    Norway  http://www.azair.eu/azfin.php?searchtype=flexi...
# 11  Austria    Poland  http://www.azair.eu/azfin.php?searchtype=flexi...
# ...
